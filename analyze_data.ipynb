# %%
import matplotlib.pyplot as plt
import json

# %%
smells = json.load(open('../code_smells.json','r'))

# %%
xAxis = [key for key in smells.keys()]
yAxis = [value for value in smells.values()]

# %%
plt.figure(figsize=(12, 6)) 
bars = plt.bar(range(len(smells)), yAxis, width=0.5, color='blue')


for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')

plt.xticks(range(len(smells)), xAxis, rotation=90)

plt.xlabel('Issues')
plt.ylabel('Occurrences')
plt.title('Top 20 Code Smells')

plt.tight_layout()  
plt.show()
# Out:
# /var/folders/13/dwkgfwbj4l3ds6lcxj_wjqph0000gn/T/ipykernel_8029/1426640524.py:15: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
